# %% [markdown]
# # Exercice 2
#
# ## __Partie A__
#
# 1) Le masque de sous réseau avec 16 bits est 225.225.0.0.
# 2) L'adresse du réseau est 172.16.0.0 sous 16 bits.
# 3) L'adresse de diffusion est 172.16.10.10 sous 16 bits.
# 4) 2^16 = 65 536, donc 65 534 peuvent etre connecté au réseaux en enlevant la machine réseau et une pour la diffusion.
# 5) Pour envoyer un message envoyé du réseau de L1 vers L2: S1 --> A --> B --> C --> D --> S2.
# 6) ![image-2.png](attachment:image-2.png)
# 7) S1 -- >A --> H --> C --> D S2
# Pour le chemin AHCD le routeur qui va etre modifié en consequence est le routeur H,
#
# |routeur|destination|passerelle|interface|
# |---    |:-:        |:-:       |--:      |
# |H      |L2         |53.10.10.6|53.10.10.10|
